# %% [markdown]
# <a href="https://colab.research.google.com/github/ANIIIITMK/ANIKET/blob/master/Copy_of_AnalysisofCOVID_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
url = 'https://raw.githubusercontent.com/ANIIIITMK/ANIKET/master/IndividualDetails.csv'

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/ANIIIITMK/ANIKET/master/IndividualDetails.csv')

# %%
df1
# Out:
#           id  ...                                              notes
# 0          0  ...                               Travelled from Wuhan
# 1          1  ...                               Travelled from Wuhan
# 2          2  ...                               Travelled from Wuhan
# 3          3  ...                      Travelled from Austria, Italy
# 4          4  ...  Travelled from Dubai to Bangalore on 20th Feb,...
# ...      ...  ...                                                ...
# 27885  27886  ...                                    Details awaited
# 27886  27887  ...                                    Details awaited
# 27887  27888  ...                                    Details awaited
# 27888  27889  ...                                    Details awaited
# 27889  27890  ...                                    Details awaited
#
# [27890 rows x 12 columns]

# %%
df1.head()
# Out:
#    id  ...                                              notes
# 0   0  ...                               Travelled from Wuhan
# 1   1  ...                               Travelled from Wuhan
# 2   2  ...                               Travelled from Wuhan
# 3   3  ...                      Travelled from Austria, Italy
# 4   4  ...  Travelled from Dubai to Bangalore on 20th Feb,...
#
# [5 rows x 12 columns]

# %%
df1.columns
# Out:
# Index(['id', 'government_id', 'diagnosed_date', 'age', 'gender',
#        'detected_city', 'detected_district', 'detected_state', 'nationality',
#        'current_status', 'status_change_date', 'notes'],
#       dtype='object')

# %%
df1.tail()
# Out:
#           id government_id  ... status_change_date            notes
# 27885  27886           NaN  ...         26/04/2020  Details awaited
# 27886  27887           NaN  ...         26/04/2020  Details awaited
# 27887  27888           NaN  ...         26/04/2020  Details awaited
# 27888  27889           NaN  ...         26/04/2020  Details awaited
# 27889  27890           NaN  ...         26/04/2020  Details awaited
#
# [5 rows x 12 columns]

# %%
df1.describe()
# Out:
#                  id
# count  27890.000000
# mean   13945.343134
# std     8051.522929
# min        0.000000
# 25%     6973.250000
# 50%    13945.500000
# 75%    20917.750000
# max    27890.000000

# %%
df1.isnull().sum()
# Out:
# id                        0
# government_id         24893
# diagnosed_date            0
# age                   25544
# gender                22577
# detected_city         25543
# detected_district      7650
# detected_state            0
# nationality           25183
# current_status            0
# status_change_date      110
# notes                  1335
# dtype: int64

# %% [markdown]
# **#Relating to the variable with scatterplots**

# %%
sns.relplot(x="diagnosed_date",y="current_status",data=df1)

# %%
sns.relplot(x="diagnosed_date",y="detected_city",data=df1)

# %%
sns.relplot(x="diagnosed_date",y="notes",data=df1)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:856: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout()

# %%
sns.relplot(x="diagnosed_date",y="status_change_date",data=df1)

# %%
sns.relplot(x="diagnosed_date",y="current_status",hue='gender',data=df1)

# %%
sns.relplot(x="diagnosed_date",y="current_status",hue='gender',data=df1)

# %%
sns.pairplot(df1)

# %%
df1.columns
# Out:
# Index(['id', 'government_id', 'diagnosed_date', 'age', 'gender',
#        'detected_city', 'detected_district', 'detected_state', 'nationality',
#        'current_status', 'status_change_date', 'notes'],
#       dtype='object')

# %%
df1
# Out:
#           id  ...                                              notes
# 0          0  ...                               Travelled from Wuhan
# 1          1  ...                               Travelled from Wuhan
# 2          2  ...                               Travelled from Wuhan
# 3          3  ...                      Travelled from Austria, Italy
# 4          4  ...  Travelled from Dubai to Bangalore on 20th Feb,...
# ...      ...  ...                                                ...
# 27885  27886  ...                                    Details awaited
# 27886  27887  ...                                    Details awaited
# 27887  27888  ...                                    Details awaited
# 27888  27889  ...                                    Details awaited
# 27889  27890  ...                                    Details awaited
#
# [27890 rows x 12 columns]

# %%
sns.catplot(x="diagnosed_date",y="status_change_date",data=df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-f64cb5bb8b9a> in <module>()
# ----> 1 sns.catplot(x="diagnosed_date",y="status_change_date",data=df1)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3721     # facets to ensure representation of all data in the final plot
#    3722     p = _CategoricalPlotter()
# -> 3723     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3724     order = p.group_names
#    3725     hue_order = p.hue_names
#
# ...
